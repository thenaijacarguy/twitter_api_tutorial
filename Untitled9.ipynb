# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/UEFA_Champions_League'

# %%
tables = pd.read_html(url)

# %%
tables[4]
# Out:
#    Rank             Player     Nation  Apps      Years  \
# 0     1  Cristiano Ronaldo   Portugal   183      2003–
# 1     2      Iker Casillas      Spain   177  1999–2019
# 2     3       Lionel Messi  Argentina   156      2005–
# 3     4               Xavi      Spain   151  1998–2015
# 4     5               Raúl      Spain   142  1995–2011
# 5     5      Karim Benzema     France   142      2005–
# 6     7         Ryan Giggs      Wales   141  1993–2014
# 7     8      Thomas Müller    Germany   134      2009–
# 8     9     Andrés Iniesta      Spain   130  2002–2018
# 9    10       Sergio Ramos      Spain   129      2005–
#
#                                       Club(s) (Apps)
# 0  Manchester United (59)Real Madrid (101)Juventu...
# 1                        Real Madrid (150)Porto (27)
# 2             Barcelona (149)Paris Saint-Germain (7)
# 3                                          Barcelona
# 4                   Real Madrid (130)Schalke 04 (12)
# ...

# %%
tables = soup.find('table')

# %%
table2 = soup.find('table', {'class':'wikitable'})

# %%
df2 = pd.read_html(str(table2))

# %%
table3 = soup.find('table', {'class':'wikitable', 'class':'sortable'})

# %%
df3 = pd.read_html(str(table3))

# %%
df3 = pd.DataFrame(df3[0])

# %%
df3
# Out:
#    .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vte Club  \
# 0                                         Real Madrid
# 1                                            AC Milan
# 2                                       Bayern Munich
# ...

# %%
df2 = pd.DataFrame(df2[0])

# %%
df2
# Out:
#                          Unnamed: 0                        Unnamed: 1  \
# 0        Preliminary round(4 teams)        Preliminary round(4 teams)
# 1  First qualifying round(34 teams)  First qualifying round(34 teams)
# 2           Second qualifying round          Champions Path(20 teams)
# 3           Second qualifying round              League Path(6 teams)
# 4            Third qualifying round          Champions Path(12 teams)
# 5            Third qualifying round              League Path(8 teams)
# 6                    Play-off round           Champions Path(8 teams)
# 7                    Play-off round              League Path(4 teams)
# 8             Group stage(32 teams)             Group stage(32 teams)
# 9          Knockout phase(16 teams)          Knockout phase(16 teams)
#
#                         Teams entering in this round  \
# 0                4 champions from associations 52–55
# 1  33 champions from associations 18–51 (except L...
# ...

# %%
import pandas as pd

# %%
df = pd.read_html(str(tables))

# %%
df = pd.DataFrame(df[0])

# %%
df
# Out:
#                                 0  \
# 0                             NaN
# 1                 Organising body
# 2                         Founded
# 3                          Region
# 4                 Number of teams
# 5                   Qualifier for
# 6            Related competitions
# 7               Current champions
# 8         Most successful club(s)
# 9         Television broadcasters
# 10                        Website
# 11  2022–23 UEFA Champions League
#
#                                                     1
# 0                                                 NaN
# 1                                                UEFA
# 2               1955; 67 years ago(rebranded in 1992)
# 3                                              Europe
# 4              32 (group stage)79 or 80 or 81 (total)
# 5                   UEFA Super CupFIFA Club World Cup
# 6   UEFA Europa League (2nd tier)UEFA Europa Confe...
# 7                            Real Madrid (14th title)
# ...

# %%
url = 'https://en.wikipedia.org/wiki/UEFA_Champions_League'

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup.title
# Out:
# <title>UEFA Champions League - Wikipedia</title>

# %%
table = soup.find('table')

# %%
table2 = soup.find('table', {'class':'wikitable'})

# %%
table3 = soup.find('table', {'class':'wikitable', 'class':'sortable'})

# %%
df3 = pd.read_html(str(table3))

# %%
df3 = pd.DataFrame(df3[0])

# %%
df3
# Out:
#    .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vte Club  \
# 0                                         Real Madrid
# 1                                            AC Milan
# 2                                       Bayern Munich
# ...

# %%
df2 = pd.read_html(str(table2))

# %%
df2 = pd.DataFrame(df2[0])

# %%
df2
# Out:
#                          Unnamed: 0                        Unnamed: 1  \
# 0        Preliminary round(4 teams)        Preliminary round(4 teams)
# 1  First qualifying round(34 teams)  First qualifying round(34 teams)
# 2           Second qualifying round          Champions Path(20 teams)
# 3           Second qualifying round              League Path(6 teams)
# 4            Third qualifying round          Champions Path(12 teams)
# 5            Third qualifying round              League Path(8 teams)
# 6                    Play-off round           Champions Path(8 teams)
# 7                    Play-off round              League Path(4 teams)
# 8             Group stage(32 teams)             Group stage(32 teams)
# 9          Knockout phase(16 teams)          Knockout phase(16 teams)
#
#                         Teams entering in this round  \
# 0                4 champions from associations 52–55
# 1  33 champions from associations 18–51 (except L...
# ...

# %%
import pandas as pd

# %%
df = pd.read_html(str(table))

# %%
df = pd.DataFrame(df[0])

# %%
df
# Out:
#                                 0  \
# 0                             NaN
# 1                 Organising body
# 2                         Founded
# 3                          Region
# 4                 Number of teams
# 5                   Qualifier for
# 6            Related competitions
# 7               Current champions
# 8         Most successful club(s)
# 9         Television broadcasters
# 10                        Website
# 11  2022–23 UEFA Champions League
#
#                                                     1
# 0                                                 NaN
# 1                                                UEFA
# 2               1955; 67 years ago(rebranded in 1992)
# 3                                              Europe
# 4              32 (group stage)79 or 80 or 81 (total)
# 5                   UEFA Super CupFIFA Club World Cup
# 6   UEFA Europa League (2nd tier)UEFA Europa Confe...
# 7                            Real Madrid (14th title)
# ...

# %%
tables = pd.read_html(url)

# %%
tables[4]
# Out:
#    Rank             Player     Nation  Apps      Years  \
# 0     1  Cristiano Ronaldo   Portugal   183      2003–
# 1     2      Iker Casillas      Spain   177  1999–2019
# 2     3       Lionel Messi  Argentina   156      2005–
# 3     4               Xavi      Spain   151  1998–2015
# 4     5               Raúl      Spain   142  1995–2011
# 5     5      Karim Benzema     France   142      2005–
# 6     7         Ryan Giggs      Wales   141  1993–2014
# 7     8      Thomas Müller    Germany   134      2009–
# 8     9     Andrés Iniesta      Spain   130  2002–2018
# 9    10       Sergio Ramos      Spain   129      2005–
#
#                                       Club(s) (Apps)
# 0  Manchester United (59)Real Madrid (101)Juventu...
# 1                        Real Madrid (150)Porto (27)
# 2             Barcelona (149)Paris Saint-Germain (7)
# 3                                          Barcelona
# 4                   Real Madrid (130)Schalke 04 (12)
# ...

# %%
url = 'https://en.wikipedia.org/wiki/UEFA_Champions_League'

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup.title
# Out:
# <title>UEFA Champions League - Wikipedia</title>

# %%
table = soup.find('table')

# %%
table2 = soup.find('table', class_='wikitable')

# %%
df2 = pd.read_html(str(table2))

# %%
df2 = pd.DataFrame(df2[0])

# %%
table3 = soup.find('table', {'class':'wikitable', 'class':'sortable'})

# %%
df3 = pd.read_html(str(table3))

# %%
df3 = pd.DataFrame(df3[0])

# %%
df3
# Out:
#    .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vte Club  \
# 0                                         Real Madrid
# 1                                            AC Milan
# 2                                       Bayern Munich
# ...

# %%
df2
# Out:
#                          Unnamed: 0                        Unnamed: 1  \
# 0        Preliminary round(4 teams)        Preliminary round(4 teams)
# 1  First qualifying round(34 teams)  First qualifying round(34 teams)
# 2           Second qualifying round          Champions Path(20 teams)
# 3           Second qualifying round              League Path(6 teams)
# 4            Third qualifying round          Champions Path(12 teams)
# 5            Third qualifying round              League Path(8 teams)
# 6                    Play-off round           Champions Path(8 teams)
# 7                    Play-off round              League Path(4 teams)
# 8             Group stage(32 teams)             Group stage(32 teams)
# 9          Knockout phase(16 teams)          Knockout phase(16 teams)
#
#                         Teams entering in this round  \
# 0                4 champions from associations 52–55
# 1  33 champions from associations 18–51 (except L...
# ...

# %%
table
# Out:
# <table class="infobox football"><caption class="infobox-title">UEFA Champions League</caption><tbody><tr><td class="infobox-image" colspan="2"><a class="image" href="/wiki/File:UEFA_Champions_League_logo_2.svg"><img alt="UEFA Champions League logo 2.svg" data-file-height="210" data-file-width="221" decoding="async" height="190" src="//upload.wikimedia.org/wikipedia/en/thumb/b/bf/UEFA_Champions_League_logo_2.svg/200px-UEFA_Champions_League_logo_2.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/b/bf/UEFA_Champions_League_logo_2.svg/300px-UEFA_Champions_League_logo_2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/b/bf/UEFA_Champions_League_logo_2.svg/400px-UEFA_Champions_League_logo_2.svg.png 2x" width="200"/></a></td></tr><tr><th class="infobox-label" scope="row">Organising body</th><td class="infobox-data"><a href="/wiki/UEFA" title="UEFA">UEFA</a></td></tr><tr><th class="infobox-label" scope="row">Founded</th><td class="infobox-data">1955<span class="noprint">; 67
# ...

# %%
import pandas as pd

# %%
df = pd.read_html(str(table))

# %%
df = pd.DataFrame(df[0])

# %%
df
# Out:
#                                 0  \
# 0                             NaN
# 1                 Organising body
# 2                         Founded
# 3                          Region
# 4                 Number of teams
# 5                   Qualifier for
# 6            Related competitions
# 7               Current champions
# 8         Most successful club(s)
# 9         Television broadcasters
# 10                        Website
# 11  2022–23 UEFA Champions League
#
#                                                     1
# 0                                                 NaN
# 1                                                UEFA
# 2               1955; 67 years ago(rebranded in 1992)
# 3                                              Europe
# 4              32 (group stage)79 or 80 or 81 (total)
# 5                   UEFA Super CupFIFA Club World Cup
# 6   UEFA Europa League (2nd tier)UEFA Europa Confe...
# 7                            Real Madrid (14th title)
# ...

# %%
url = 'https://en.wikipedia.org/wiki/UEFA_Champions_League'

# %%
table = pd.read_html(url)

# %%
table[3]
# Out:
#            Nation  Titles  Runners-up  Total
# 0           Spain      19          11     30
# 1         England      14          11     25
# 2           Italy      12          16     28
# 3      Germany[a]       8          10     18
# 4     Netherlands       6           2      8
# 5        Portugal       4           5      9
# 6          France       1           6      7
# 7         Romania       1           1      2
# 8        Scotland       1           1      2
# 9   Yugoslavia[b]       1           1      2
# 10        Belgium       0           1      1
# 11         Greece       0           1      1
# 12         Sweden       0           1      1

# %%
response.status_code
# Out:
# 200

# %%
response = requests.get(url)

# %%
soup.title
# Out:
# <title>UEFA Champions League - Wikipedia</title>

# %%
table = soup.find('table')

# %%
df = pd.read_html(str(table))

# %%
df = pd.DataFrame(df[0])

# %%
df
# Out:
#                                 0  \
# 0                             NaN
# 1                 Organising body
# 2                         Founded
# 3                          Region
# 4                 Number of teams
# 5                   Qualifier for
# 6            Related competitions
# 7               Current champions
# 8         Most successful club(s)
# 9         Television broadcasters
# 10                        Website
# 11  2022–23 UEFA Champions League
#
#                                                     1
# 0                                                 NaN
# 1                                                UEFA
# 2               1955; 67 years ago(rebranded in 1992)
# 3                                              Europe
# 4                          32 (group stage)80 (total)
# 5                   UEFA Super CupFIFA Club World Cup
# 6   UEFA Europa League (2nd tier)UEFA Europa Confe...
# 7                            Real Madrid (14th title)
# ...

# %%
import requests
import os
import pandas as pd

# %%
os.makedirs('data_wrangling')

# %%
url = 'https://www.rogerebert.com/reviews/great-movie-superman-1978'

# %%
response = requests.get(url)

# %%
with open (os.path.join('data_wrangling', 'Superman'), mode='wb') as file:
    file.write(response.content)

# %%
os.listdir('data_wrangling')
# Out:
# ['Superman']

# %%
import wptools

# %%
page = wptools.page('UEFA_Champions_League')

# %%
page

# %%
live = 'https://www.livescores.com/?tz=-7'

# %%
response2 = requests.get(live)

# %%
soup2 = BeautifulSoup(response2.content, 'html.parser')

# %%
souptable = soup2.find('table')

# %%
souptable

# %%
from bs4 import BeautifulSoup

# %%
wikiurl = 'https://en.wikipedia.org/wiki/UEFA_Champions_League'

# %%
response = requests.get(wikiurl)

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup.title
# Out:
# <title>UEFA Champions League - Wikipedia</title>

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   UEFA Champions League - Wikipedia\n  </title>\n  <script>\n   document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"d48621fb-f2be-423e-8816-0fee15e92d53","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"UEFA_Champions_League","wgTitle":"UEFA Champions League","wgCurRevisionId":1103672337,"wgRevisionId":1103672337,"wgArticleId":44220,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 Italian-language sources (it)","CS1 errors: missing periodical","Articles with short description",
# ...

# %%
uefa = soup.find_all('table', {'class':"wikitable", 'class':'sortable'})

# %%
uefa[2]
# Out:
# <table class="wikitable sortable plainrowheaders" style="text-align:center;">
# <tbody><tr>
# <th scope="col">Rank
# </th>
# <th scope="col">Player
# </th>
# <th scope="col">Nation
# </th>
# <th scope="col"><abbr title="Appearances">Apps</abbr>
# </th>
# <th scope="col">Years
# </th>
# <th scope="col">Club(s) (<abbr title="Appearances">Apps</abbr>)
# </th></tr>
# <tr>
# <td>1
# </td>
# <th data-sort-value="Ronaldo, Cristiano" scope="row"><b><a href="/wiki/Cristiano_Ronaldo" title="Cristiano Ronaldo">Cristiano Ronaldo</a></b>
# </th>
# ...

# %%
df1 = pd.read_html(str(uefa))

# %%
df2 = pd.DataFrame(df1[0])

# %%
df2.head()
# Out:
#   .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vte Club  \
# 0                                        Real Madrid
# 1                                           AC Milan
# 2                                      Bayern Munich
# ...

# %%
df2.rename(columns={df2.columns[0]:'Club'}, inplace=True)

# %%
df2.head()
# Out:
#             Club  Title(s)  Runners-up  \
# 0    Real Madrid        14           3
# 1       AC Milan         7           4
# 2  Bayern Munich         6           5
# 3      Liverpool         6           4
# 4      Barcelona         5           3
#
#                                          Seasons won  \
# 0  1956, 1957, 1958, 1959, 1960, 1966, 1998, 2000...
# 1           1963, 1969, 1989, 1990, 1994, 2003, 2007
# 2                 1974, 1975, 1976, 2001, 2013, 2020
# 3                 1977, 1978, 1981, 1984, 2005, 2019
# 4                       1992, 2006, 2009, 2011, 2015
#
#               Seasons runner-up
# 0              1962, 1964, 1981
# 1        1958, 1993, 1995, 2005
# 2  1982, 1987, 1999, 2010, 2012
# 3        1985, 2007, 2018, 2022
# 4              1961, 1986, 1994

# %%
tables = pd.read_html(wikiurl)

# %%
len(tables)
# Out:
# 22

# %%
tables[2]
# Out:
#    .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vte Club  \
# 0                                         Real Madrid
# 1                                            AC Milan
# 2                                       Bayern Munich
# ...

# %%
chart = 'https://www.turntablecharts.com/Charts/Top50'

# %%
chart_table = pd.read_html(chart)

# %%
chart_table[0]
# Out:
#           Rank                                            Entry Last Week  \
# 0            1                       BandanaFireboy DML & Asake         1
# 1         2NEW                   MachalaCarter Efe & Berri-Tiga       NaN
# 2            3                             It's PlentyBurna Boy         7
# 3            4                    Peace Be Unto You (PBUY)Asake         2
# 4            5              For My HandBurna Boy ft. Ed Sheeran         3
# ..         ...                                              ...       ...
# 95  96RE-ENTRY  Second Sermon (Remix)Black Sherif ft. Burna Boy         *
# 96          97                                   LieKizz Daniel        98
# 97          98                   Jimmy CooksDrake ft. 21 Savage        71
# 98          99                     How Bad Could It BeBurna Boy        79
# 99         100                                   Emi Lo KanQdot        91
#
#     Peak
# 0      1
# 1      2
# 2      3
# 3      1
# 4      1
# ..   ...
# ...

# %%
from sqlalchemy import create_engine

# %%
pip install tweepy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import configparser

# %%
import tweepy

# %%
config = configparser.ConfigParser()
config.read('config.ini')
# Out:
# ['config.ini']

# %%
api_key = config['twitter']['api_key']
api_key_secret = config['twitter']['api_key_secret']
access_token = config['twitter']['access_token']
access_token_secret = config['twitter']['access_token_secret']

# %%
auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
screen_name = "thenaijacarguy"
user = api.get_user(screen_name=screen_name)
user.id
# Out:
# 199356508

# %%
user_id = "199356508"
user1 = api.get_user(user_id = user_id)
user1.name
# Out:
# 'Gabby'

# %%
user.description
# Out:
# 'Data Analyst - Session Lead @Udacity | | Car Guy by day, Data Analyst by night. Clueless in between.'

# %%
user.followers_count
# Out:
# 3739

# %%
tweet_id = 

with open('tweet_json.txt', w) as file:
    file.write()

# %%
tweet = api.get_status(892420643555336193)

# %%
tweet.user.location
# Out:
# 'all our links ➜'
